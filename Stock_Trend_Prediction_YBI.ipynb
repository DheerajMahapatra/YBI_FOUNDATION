# %%
import yfinance as yf

# %%
from datetime import datetime
end = datetime.now()
start = datetime(end.year - 20, end.month, end.day)

# %%
stock = "AAPL"
apple_data = yf.download(stock, start, end, auto_adjust=False)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
apple_data.head(10)
# Out:
# Price      Adj Close     Close      High       Low      Open      Volume
# Ticker          AAPL      AAPL      AAPL      AAPL      AAPL        AAPL
# Date
# 2005-07-11  1.145064  1.360714  1.380357  1.349286  1.370357   388788400
# 2005-07-12  1.149272  1.365714  1.371429  1.353929  1.365357   387038400
# 2005-07-13  1.152578  1.369643  1.375000  1.353571  1.367500   684835200
# 2005-07-14  1.224708  1.455357  1.500357  1.436786  1.456786  2096060400
# 2005-07-15  1.248752  1.483929  1.484643  1.445000  1.463214   687682800
# 2005-07-18  1.246948  1.481786  1.503571  1.477500  1.478929   586297600
# 2005-07-19  1.298040  1.542500  1.543929  1.466786  1.482857   671062000
# 2005-07-20  1.311263  1.558214  1.564286  1.523214  1.530714   453395600
# 2005-07-21  1.301046  1.546071  1.572857  1.532143  1.560714   404264000
# 2005-07-22  1.322384  1.571429  1.571429  1.549643  1.551429   301106400

# %%
apple_data.shape
# Out:
# (5030, 6)

# %%
apple_data.describe()
# Out:
# Price     Adj Close        Close         High          Low         Open  \
# Ticker         AAPL         AAPL         AAPL         AAPL         AAPL
# count   5030.000000  5030.000000  5030.000000  5030.000000  5030.000000
# mean      56.825425    58.723760    59.315205    58.073273    58.676173
# std       67.769688    67.792359    68.463345    67.037394    67.715649
# min        1.145064     1.360714     1.371429     1.349286     1.365357
# 25%        7.750374     9.210000     9.283036     9.102411     9.207589
# 50%       24.379128    27.000000    27.233750    26.725000    27.002501
# 75%       89.789427    92.369373    93.063751    90.960627    91.791876
# max      258.396667   259.019989   260.100006   257.630005   258.190002
#
# Price         Volume
# Ticker          AAPL
# count   5.030000e+03
# mean    3.662498e+08
# std     3.835755e+08
# min     2.323470e+07
# 25%     9.427325e+07
# 50%     2.028470e+08
# 75%     5.292658e+08
# max     3.372970e+09

# %%
apple_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5030 entries, 2005-07-11 to 2025-07-08
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   (Adj Close, AAPL)  5030 non-null   float64
#  1   (Close, AAPL)      5030 non-null   float64
#  2   (High, AAPL)       5030 non-null   float64
#  3   (Low, AAPL)        5030 non-null   float64
#  4   (Open, AAPL)       5030 non-null   float64
#  5   (Volume, AAPL)     5030 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 275.1 KB

# %%
apple_data.isna().sum()
# Out:
# Price      Ticker
# Adj Close  AAPL      0
# Close      AAPL      0
# High       AAPL      0
# Low        AAPL      0
# Open       AAPL      0
# Volume     AAPL      0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (15,5))
apple_data['Adj Close'].plot()
plt.xlabel("years")
plt.ylabel("Adj Close")
plt.title("Closing price of Apple data")
# Out:
# Text(0.5, 1.0, 'Closing price of Apple data')

# %%
def plot_graph(figsize, values, column_name):
    plt.figure(figsize=figsize)
    values.plot()
    plt.xlabel("Years")
    plt.ylabel(column_name)
    plt.title(f"{column_name} of Apple data")
    plt.tight_layout()

# %%
apple_data.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             (    'Close', 'AAPL'),
#             (     'High', 'AAPL'),
#             (      'Low', 'AAPL'),
#             (     'Open', 'AAPL'),
#             (   'Volume', 'AAPL')],
#            names=['Price', 'Ticker'])

# %%
for column in apple_data.columns:
    plot_graph((15, 5), apple_data[column], column)

# %%
apple_data['MA_for_250_days'] = apple_data['Adj Close'].rolling(250).mean()

# %%
apple_data['MA_for_250_days'][0:250].tail()
# Out:
# Date
# 2006-06-29        NaN
# 2006-06-30        NaN
# 2006-07-03        NaN
# 2006-07-05        NaN
# 2006-07-06    1.83851
# Name: MA_for_250_days, dtype: float64

# %%
plot_graph((15,5), apple_data['MA_for_250_days'], 'MA_for_250_days')

# %%
apple_data['MA_for_100_days'] = apple_data['Adj Close'].rolling(100).mean()
plot_graph((15,5), apple_data[['Adj Close','MA_for_100_days']], 'MA_for_100_days')

# %%
plot_graph((15,5), apple_data[['Adj Close','MA_for_100_days', 'MA_for_250_days']], 'MA')

# %%
apple_data['percentage_change_cp'] = apple_data['Adj Close'].pct_change()
apple_data[['Adj Close','percentage_change_cp']].head()
# Out:
# Price      Adj Close percentage_change_cp
# Ticker          AAPL
# Date
# 2005-07-11  1.145064                  NaN
# 2005-07-12  1.149272             0.003675
# 2005-07-13  1.152578             0.002877
# 2005-07-14  1.224708             0.062581
# 2005-07-15  1.248752             0.019632

# %%
plot_graph((15,5), apple_data['percentage_change_cp'], 'percentage_change')

# %%
Adj_close_price = apple_data[['Adj Close']]

# %%
max(Adj_close_price.values),min(Adj_close_price.values)
# Out:
# (array([258.39666748]), array([1.145064]))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(Adj_close_price)
scaled_data
# Out:
# array([[0.00000000e+00],
#        [1.63574052e-05],
#        [2.92101486e-05],
#        ...,
#        [8.25670030e-01],
#        [8.11675924e-01],
#        [8.11909149e-01]])

# %%
len(scaled_data)
# Out:
# 5030

# %%
x_data=[]
y_data=[]
for i in range(100, len(scaled_data)):
    x_data.append(scaled_data[i-100:i])
    y_data.append(scaled_data[i])

import numpy as np
x_data, y_data = np.array(x_data), np.array(y_data)

# %%
x_data[0],y_data[0]
# Out:
# (array([[0.00000000e+00],
#         [1.63574052e-05],
#         [2.92101486e-05],
#         [3.09596528e-04],
#         [4.03059272e-04],
#         [3.96048558e-04],
#         [5.94655326e-04],
#         [6.46057495e-04],
#         [6.06338458e-04],
#         [6.89288144e-04],
#         [6.67090563e-04],
#         [6.46057495e-04],
#         [6.88118070e-04],
#         [6.65922806e-04],
#         [5.31567244e-04],
#         [5.43253157e-04],
#         [5.94655326e-04],
#         [5.98159524e-04],
#         [5.38579811e-04],
#         [5.71289987e-04],
#         [5.31567244e-04],
#         [6.68257393e-04],
#         [6.16853834e-04],
#         [6.89288144e-04],
#         [9.34626979e-04],
#         [1.11921325e-03],
#         [9.52150751e-04],
#         [1.05729524e-03],
#         [9.57990000e-04],
#         [9.03084096e-04],
#         [9.07753735e-04],
#         [8.92567331e-04],
#         [8.96071529e-04],
#         [9.29952243e-04],
#         [8.92567331e-04],
#         [9.04251390e-04],
#         [9.89533346e-04],
#         [1.02692104e-03],
#         [9.53318045e-04],
#         [9.48642846e-04],
#         [1.25006090e-03],
#         [1.23604040e-03],
#         [1.36455347e-03],
#         [1.54329956e-03],
#         [1.55381262e-03],
#         [1.48605444e-03],
#         [1.34469233e-03],
#         [1.37506421e-03],
#         [1.53161597e-03],
#         [1.69868078e-03],
#         [1.76293615e-03],
#         [1.63675953e-03],
#         [1.61222643e-03],
#         [1.76410298e-03],
#         [1.83887374e-03],
#         [1.79214259e-03],
#         [1.51642910e-03],
#         [1.66363323e-03],
#         [1.81200512e-03],
#         [1.90897160e-03],
#         [1.82835975e-03],
#         [1.71503679e-03],
#         [1.58886387e-03],
#         [1.54213319e-03],
#         [1.43348266e-03],
#         [1.57601252e-03],
#         [1.30263500e-03],
#         [1.82719199e-03],
#         [1.85756573e-03],
#         [1.79214259e-03],
#         [1.64844405e-03],
#         [1.96738588e-03],
#         [2.10757930e-03],
#         [2.05150054e-03],
#         [2.18351595e-03],
#         [2.10290317e-03],
#         [2.21155695e-03],
#         [2.02229642e-03],
#         [1.91247627e-03],
#         [2.27698194e-03],
#         [2.26646379e-03],
#         [2.55269127e-03],
#         [2.77466847e-03],
#         [2.69288793e-03],
#         [2.58540283e-03],
#         [2.54685248e-03],
#         [2.57138882e-03],
#         [2.69639074e-03],
#         [2.73844807e-03],
#         [2.72793640e-03],
#         [2.82490659e-03],
#         [3.13683353e-03],
#         [3.08659403e-03],
#         [3.09126876e-03],
#         [3.13800129e-03],
#         [3.32025158e-03],
#         [3.38918401e-03],
#         [3.64970693e-03],
#         [3.68709833e-03],
#         [3.50484202e-03]]),
#  array([0.00347213]))

# %%
int(len(x_data)*0.7)
# Out:
# 3451

# %%
5030-100-int(len(x_data)*0.7)
# Out:
# 1479

# %%
splitting_len = int(len(x_data)*0.7)
x_train = x_data[:splitting_len]
y_train = y_data[:splitting_len]

x_test = x_data[splitting_len:]
y_test = y_data[splitting_len:]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3451, 100, 1)
# (3451, 1)
# (1479, 100, 1)
# (1479, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(64,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size=1, epochs = 2)
# Out:
# Epoch 1/2
# 3451/3451 ━━━━━━━━━━━━━━━━━━━━ 277s 79ms/step - loss: 1.4031e-04
# Epoch 2/2
# 3451/3451 ━━━━━━━━━━━━━━━━━━━━ 306s 75ms/step - loss: 3.2096e-05

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 100, 128)       │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 25)             │         1,625 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 352,859 (1.35 MB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 235,240 (918.91 KB)

# %%
predictions = model.predict(x_test)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 58ms/step

# %%
predictions
# Out:
# array([[0.18805298],
#        [0.19047238],
#        [0.19226487],
#        ...,
#        [0.8031506 ],
#        [0.8132381 ],
#        [0.8115248 ]], dtype=float32)

# %%
inv_predictions = scaler.inverse_transform(predictions)
inv_predictions
# Out:
# array([[ 49.521996],
#        [ 50.144386],
#        [ 50.60551 ],
#        ...,
#        [207.75685 ],
#        [210.35187 ],
#        [209.91112 ]], dtype=float32)

# %%
inv_y_test = scaler.inverse_transform(y_test)
inv_y_test
# Out:
# array([[ 50.70773697],
#        [ 50.71014404],
#        [ 51.25976944],
#        ...,
#        [213.55000305],
#        [209.94999695],
#        [210.00999451]])

# %%
rmse = np.sqrt(np.mean( (inv_predictions - inv_y_test)**2))

# %%
rmse
# Out:
# np.float64(3.545662642169622)

# %%
import pandas as pd
ploting_data = pd.DataFrame(
 {
  'original_test_data': inv_y_test.reshape(-1),
    'predictions': inv_predictions.reshape(-1)
 } ,
    index = apple_data.index[splitting_len+100:]
)
ploting_data.head()
# Out:
#             original_test_data  predictions
# Date
# 2019-08-19           50.707737    49.521996
# 2019-08-20           50.710144    50.144386
# 2019-08-21           51.259769    50.605511
# 2019-08-22           51.216381    51.063801
# 2019-08-23           48.849140    51.298954

# %%
plot_graph((15,6), ploting_data, 'test data')

# %%
plot_graph((15,6), pd.concat([Adj_close_price[:splitting_len+100],ploting_data], axis=0), 'whole data')

# %%
model.save("Latest_stock_price_model.keras")

# %%
from google.colab import files
files.download("Latest_stock_price_model.keras")
